# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image,ImageFilter
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import cv2
import random

# %%
image1 = cv2.imread('saltandpaper.tif',0)
image2 = cv2.imread('smoothing.tif',0)
image3 = cv2.imread('unsharpmasking.tif',0)


image1 = cv2.resize(image1, (400,400))
image2 = cv2.resize(image2, (400,400))
image3 = cv2.resize(image3, (400,400))

# %%
def averagingFilter(image, filter):
    w = filter.shape[0]
    size = filter.shape[0] * filter.shape[1]
    for i in range(image.shape[0]):
        if (i < image.shape[0] - 2):
            for j in range(image.shape[1]):
                if (j < image.shape[0] - 2):
                    block = image[j:j+w,i:i + w]
                    pixel = sum(sum(block *kernel)) / size
                    image[i][j] = pixel

    return Image.fromarray(image)

# %% [markdown]
# ### 3 x 3 Averaging Filter

# %%
filter_3 = np.ones((3,3))
result = averagingFilter(image1, filter_3)
result
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x124B30D68>

# %% [markdown]
# ### 5 x 5 Averaging Filter

# %%
filter_5 = np.ones((5,5))
result = averagingFilter(image1, filter_5)
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-928d39963568> in <module>
#       1 filter_5 = np.ones((5,5))
# ----> 2 result = averagingFilter(image1, filter_5)
#       3 result
#
# <ipython-input-150-dd6ed63f4445> in averagingFilter(image, filter)
#       7                 if (j < image.shape[0] - 2):
#       8                     block = image[j:j+w,i:i + w]
# ----> 9                     pixel = sum(sum(block *kernel)) / size
#      10                     image[i][j] = pixel
#      11
#
# ValueError: operands could not be broadcast together with shapes (5,5) (3,3)

# %% [markdown]
# ### 15 x 15 Averaging Filter

# %%
filter_15 = np.ones((15,15))
result = averagingFilter(image1, filter_3)
result
